# %%
from src.spark_session import get_spark
from src.utils.display_mimic import display

spark = get_spark()
# Out:
# Warning: Ignoring non-Spark config property: javax.jdo.option.ConnectionURL
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-f1866942-6ba1-4520-8999-10af8f3d8d2f;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.0.0 in central
# 	found io.delta#delta-storage;3.0.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# downloading https://repo1.maven.org/maven2/io/delta/delta-spark_2.12/3.0.0/delta-spark_2.12-3.0.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-spark_2.12;3.0.0!delta-spark_2.12.jar (526ms)
# downloading https://repo1.maven.org/maven2/io/delta/delta-storage/3.0.0/delta-storage-3.0.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-storage;3.0.0!delta-storage.jar (54ms)
# downloading https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.9.3/antlr4-runtime-4.9.3.jar ...
# 	[SUCCESSFUL ] org.antlr#antlr4-runtime;4.9.3!antlr4-runtime.jar (79ms)
# :: resolution report :: resolve 3351ms :: artifacts dl 680ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.0.0 from central in [default]
# 	io.delta#delta-storage;3.0.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   3   |   3   |   0   ||   3   |   3   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-f1866942-6ba1-4520-8999-10af8f3d8d2f
# 	confs: [default]
# 	3 artifacts copied, 0 already retrieved (5230kB/58ms)
# 26/03/05 22:39:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df_sales_order_detail = spark.table('store.store_sales_order_detail')

# %%
display(df_sales_order_detail, 10)
# Out:
# 26/03/05 22:40:35 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#    SalesOrderID  SalesOrderDetailID  OrderQty  ProductID UnitPrice  \
# 0         66063               92390         1        876    120.00
# 1         66064               92391         1        783   2294.99
# 2         66064               92392         1        878     21.98
# 3         66064               92393         1        871      9.99
# 4         66065               92394         1        965    742.35
# 5         66065               92395         1        707     34.99
# 6         66066               92396         1        968   2384.07
# 7         66066               92397         1        872      8.99
# 8         66066               92398         1        712      8.99
# 9         66066               92399         1        870      4.99
#
#   UnitPriceDiscount                  loaded_at
# 0            0.0000 2026-03-05 22:36:38.255214
# 1            0.0000 2026-03-05 22:36:38.255214
# 2            0.0000 2026-03-05 22:36:38.255214
# 3            0.0000 2026-03-05 22:36:38.255214
# 4            0.0000 2026-03-05 22:36:38.255214
# 5            0.0000 2026-03-05 22:36:38.255214
# 6            0.0000 2026-03-05 22:36:38.255214
# 7            0.0000 2026-03-05 22:36:38.255214
# 8            0.0000 2026-03-05 22:36:38.255214
# 9            0.0000 2026-03-05 22:36:38.255214

# %%
spark.sql(
    '''
        SELECT *
        FROM store.store_sales_order_detail
        WHERE UnitPriceDiscount > 0
        LIMIT 10;
    '''
).show(truncate=False, vertical=True)
# Out:
# -RECORD 0----------------------------------------
#  SalesOrderID       | 43875
#  SalesOrderDetailID | 803
#  OrderQty           | 12
#  ProductID          | 773
#  UnitPrice          | 1971.99
#  UnitPriceDiscount  | 0.0200
#  loaded_at          | 2026-03-05 22:36:38.255214
# -RECORD 1----------------------------------------
#  SalesOrderID       | 43875
#  SalesOrderDetailID | 805
#  OrderQty           | 13
#  ProductID          | 775
#  UnitPrice          | 1957.49
#  UnitPriceDiscount  | 0.0200
#  loaded_at          | 2026-03-05 22:36:38.255214
# -RECORD 2----------------------------------------
#  SalesOrderID       | 43879
#  SalesOrderDetailID | 860
#  OrderQty           | 13
#  ProductID          | 712
#  UnitPrice          | 5.01
#  UnitPriceDiscount  | 0.0200
#  loaded_at          | 2026-03-05 22:36:38.255214
# -RECORD 3----------------------------------------
#  SalesOrderID       | 43881
#  SalesOrderDetailID | 881
#  OrderQty           | 21
#  ProductID          | 709
#  UnitPrice          | 5.23
#  UnitPriceDiscount  | 0.0500
#  loaded_at          | 2026-03-05 22:36:38.255214
# -RECORD 4----------------------------------------
#  SalesOrderID       | 43884
#  SalesOrderDetailID | 916
#  OrderQty           | 14
#  ProductID          | 772
#  UnitPrice          | 1971.99
#  UnitPriceDiscount  | 0.0200
#  loaded_at          | 2026-03-05 22:36:38.255214
# -RECORD 5----------------------------------------
#  SalesOrderID       | 43898
#  SalesOrderDetailID | 1039
#  OrderQty           | 13
#  ProductID          | 770
#  UnitPrice          | 405.48
#  UnitPriceDiscount  | 0.0200
#  loaded_at          | 2026-03-05 22:36:38.255214
# -RECORD 6----------------------------------------
#  SalesOrderID       | 43898
#  SalesOrderDetailID | 1051
#  OrderQty           | 11
#  ProductID          | 715
#  UnitPrice          | 27.88
#  UnitPriceDiscount  | 0.0200
#  loaded_at          | 2026-03-05 22:36:38.255214
# -RECORD 7----------------------------------------
#  SalesOrderID       | 43906
#  SalesOrderDetailID | 1145
#  OrderQty           | 26
#  ProductID          | 709
#  UnitPrice          | 4.75
#  UnitPriceDiscount  | 0.1000
#  loaded_at          | 2026-03-05 22:36:38.255214
# -RECORD 8----------------------------------------
#  SalesOrderID       | 44098
#  SalesOrderDetailID | 1644
#  OrderQty           | 22
#  ProductID          | 709
#  UnitPrice          | 5.23
#  UnitPriceDiscount  | 0.0500
#  loaded_at          | 2026-03-05 22:36:38.255214
# -RECORD 9----------------------------------------
#  SalesOrderID       | 44100
#  SalesOrderDetailID | 1660
#  OrderQty           | 11
#  ProductID          | 777
#  UnitPrice          | 1957.49
#  UnitPriceDiscount  | 0.0200
#  loaded_at          | 2026-03-05 22:36:38.255214
