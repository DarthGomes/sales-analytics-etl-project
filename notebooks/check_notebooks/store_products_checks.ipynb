# %%
from src.spark_session import get_spark
from src.utils.display_mimic import display

spark = get_spark()
# Out:
# Warning: Ignoring non-Spark config property: javax.jdo.option.ConnectionURL
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-5e4768c1-9221-4ab2-85f3-d41f8a848e76;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.0.0 in central
# 	found io.delta#delta-storage;3.0.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# downloading https://repo1.maven.org/maven2/io/delta/delta-spark_2.12/3.0.0/delta-spark_2.12-3.0.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-spark_2.12;3.0.0!delta-spark_2.12.jar (535ms)
# downloading https://repo1.maven.org/maven2/io/delta/delta-storage/3.0.0/delta-storage-3.0.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-storage;3.0.0!delta-storage.jar (48ms)
# downloading https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.9.3/antlr4-runtime-4.9.3.jar ...
# 	[SUCCESSFUL ] org.antlr#antlr4-runtime;4.9.3!antlr4-runtime.jar (76ms)
# :: resolution report :: resolve 3125ms :: artifacts dl 678ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.0.0 from central in [default]
# 	io.delta#delta-storage;3.0.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   3   |   3   |   0   ||   3   |   3   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-5e4768c1-9221-4ab2-85f3-d41f8a848e76
# 	confs: [default]
# 	3 artifacts copied, 0 already retrieved (5230kB/56ms)
# 26/03/05 21:50:20 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df_products = spark.table('store.store_products')

display(df_products, 10)
# Out:
#    ProductID                 ProductDesc ProductNumber  MakeFlag  Color  \
# 0        680   HL Road Frame - Black, 58    FR-R92B-58      True  Black
# 1        706     HL Road Frame - Red, 58    FR-R92R-58      True    Red
# 2        707       Sport-100 Helmet, Red     HL-U509-R     False    Red
# 3        708     Sport-100 Helmet, Black       HL-U509     False  Black
# 4        709      Mountain Bike Socks, M     SO-B909-M     False  White
# 5        710      Mountain Bike Socks, L     SO-B909-L     False  White
# 6        711      Sport-100 Helmet, Blue     HL-U509-B     False   Blue
# 7        712                AWC Logo Cap       CA-1098     False  Multi
# 8        713  Long-Sleeve Logo Jersey, S     LJ-0192-S     False  Multi
# 9        714  Long-Sleeve Logo Jersey, M     LJ-0192-M     False  Multi
#
#    SafetyStockLevel  ReorderPoint  Size SizeUnitMeasureCode  \
# 0               500           375    58                 CM
# 1               500           375    58                 CM
# 2                 4             3  None                None
# 3                 4             3  None                None
# 4                 4             3     M                None
# 5                 4             3     L                None
# 6                 4             3  None                None
# 7                 4             3  None                None
# 8                 4             3     S                None
# 9                 4             3     M                None
#
#   WeightUnitMeasureCode StandardCost ListPrice Weight ProductCategoryName  \
# 0                   LB       1059.31   1431.50   2.24                None
# 1                   LB       1059.31   1431.50   2.24                None
# 2                  None        13.09     34.99   None                None
# 3                  None        13.09     34.99   None                None
# 4                  None         3.40      9.50   None                None
# 5                  None         3.40      9.50   None                None
# 6                  None        13.09     34.99   None                None
# 7                  None         6.92      8.99   None                None
# 8                  None        38.49     49.99   None            Clothing
# 9                  None        38.49     49.99   None            Clothing
#
#   ProductSubCategoryName                  loaded_at
# 0            Road Frames 2026-03-05 21:47:21.646824
# 1            Road Frames 2026-03-05 21:47:21.646824
# 2                Helmets 2026-03-05 21:47:21.646824
# 3                Helmets 2026-03-05 21:47:21.646824
# 4                  Socks 2026-03-05 21:47:21.646824
# 5                  Socks 2026-03-05 21:47:21.646824
# 6                Helmets 2026-03-05 21:47:21.646824
# 7                   Caps 2026-03-05 21:47:21.646824
# 8                Jerseys 2026-03-05 21:47:21.646824
# 9                Jerseys 2026-03-05 21:47:21.646824

# %%
spark.sql(
    '''
    SELECT 
        ProductID,
        COUNT(*)
    FROM store.store_products
    GROUP BY ProductID
    HAVING COUNT(*) > 1
    '''
).show(truncate=False, vertical=True)
# Out:
# (0 rows)

# %%
spark.sql(
    '''
        SELECT *
        FROM store.store_products
        LIMIT 5;
    ''').show(truncate=False, vertical=True)
# Out:
# -RECORD 0--------------------------------------------
#  ProductID              | 680
#  ProductDesc            | HL Road Frame - Black, 58
#  ProductNumber          | FR-R92B-58
#  MakeFlag               | true
#  Color                  | Black
#  SafetyStockLevel       | 500
#  ReorderPoint           | 375
#  Size                   | 58
#  SizeUnitMeasureCode    | CM
#  WeightUnitMeasureCode  | LB
#  StandardCost           | 1059.31
#  ListPrice              | 1431.50
#  Weight                 | 2.24
#  ProductCategoryName    | NULL
#  ProductSubCategoryName | Road Frames
#  loaded_at              | 2026-03-05 21:47:21.646824
# -RECORD 1--------------------------------------------
#  ProductID              | 706
#  ProductDesc            | HL Road Frame - Red, 58
#  ProductNumber          | FR-R92R-58
#  MakeFlag               | true
#  Color                  | Red
#  SafetyStockLevel       | 500
#  ReorderPoint           | 375
#  Size                   | 58
#  SizeUnitMeasureCode    | CM
#  WeightUnitMeasureCode  | LB
#  StandardCost           | 1059.31
#  ListPrice              | 1431.50
#  Weight                 | 2.24
#  ProductCategoryName    | NULL
#  ProductSubCategoryName | Road Frames
#  loaded_at              | 2026-03-05 21:47:21.646824
# -RECORD 2--------------------------------------------
#  ProductID              | 707
#  ProductDesc            | Sport-100 Helmet, Red
#  ProductNumber          | HL-U509-R
#  MakeFlag               | false
#  Color                  | Red
#  SafetyStockLevel       | 4
#  ReorderPoint           | 3
#  Size                   | NULL
#  SizeUnitMeasureCode    | NULL
#  WeightUnitMeasureCode  | NULL
#  StandardCost           | 13.09
#  ListPrice              | 34.99
#  Weight                 | NULL
#  ProductCategoryName    | NULL
#  ProductSubCategoryName | Helmets
#  loaded_at              | 2026-03-05 21:47:21.646824
# -RECORD 3--------------------------------------------
#  ProductID              | 708
#  ProductDesc            | Sport-100 Helmet, Black
#  ProductNumber          | HL-U509
#  MakeFlag               | false
#  Color                  | Black
#  SafetyStockLevel       | 4
#  ReorderPoint           | 3
#  Size                   | NULL
#  SizeUnitMeasureCode    | NULL
#  WeightUnitMeasureCode  | NULL
#  StandardCost           | 13.09
#  ListPrice              | 34.99
#  Weight                 | NULL
#  ProductCategoryName    | NULL
#  ProductSubCategoryName | Helmets
#  loaded_at              | 2026-03-05 21:47:21.646824
# -RECORD 4--------------------------------------------
#  ProductID              | 709
#  ProductDesc            | Mountain Bike Socks, M
#  ProductNumber          | SO-B909-M
#  MakeFlag               | false
#  Color                  | White
#  SafetyStockLevel       | 4
#  ReorderPoint           | 3
#  Size                   | M
#  SizeUnitMeasureCode    | NULL
#  WeightUnitMeasureCode  | NULL
#  StandardCost           | 3.40
#  ListPrice              | 9.50
#  Weight                 | NULL
#  ProductCategoryName    | NULL
#  ProductSubCategoryName | Socks
#  loaded_at              | 2026-03-05 21:47:21.646824
