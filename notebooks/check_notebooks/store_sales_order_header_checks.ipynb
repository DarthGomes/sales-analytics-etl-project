# %%
from src.spark_session import get_spark
from src.utils.display_mimic import display

spark = get_spark()
# Out:
# Warning: Ignoring non-Spark config property: javax.jdo.option.ConnectionURL
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-353001c9-8970-4562-a8d4-81cf5218bd82;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.0.0 in central
# 	found io.delta#delta-storage;3.0.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# downloading https://repo1.maven.org/maven2/io/delta/delta-spark_2.12/3.0.0/delta-spark_2.12-3.0.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-spark_2.12;3.0.0!delta-spark_2.12.jar (592ms)
# downloading https://repo1.maven.org/maven2/io/delta/delta-storage/3.0.0/delta-storage-3.0.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-storage;3.0.0!delta-storage.jar (84ms)
# downloading https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.9.3/antlr4-runtime-4.9.3.jar ...
# 	[SUCCESSFUL ] org.antlr#antlr4-runtime;4.9.3!antlr4-runtime.jar (113ms)
# :: resolution report :: resolve 3527ms :: artifacts dl 827ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.0.0 from central in [default]
# 	io.delta#delta-storage;3.0.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   3   |   3   |   0   ||   3   |   3   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-353001c9-8970-4562-a8d4-81cf5218bd82
# 	confs: [default]
# 	3 artifacts copied, 0 already retrieved (5230kB/44ms)
# 26/03/05 22:11:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df_sales_order_header = spark.table('store.store_sales_order_header')

# %%
df_sales_order_header.printSchema()
# Out:
# root
#  |-- SalesOrderID: integer (nullable = true)
#  |-- OrderDate: timestamp (nullable = true)
#  |-- ShipDate: date (nullable = true)
#  |-- OnlineOrderFlag: boolean (nullable = true)
#  |-- AccountNumber: string (nullable = true)
#  |-- CustomerID: integer (nullable = true)
#  |-- SalesPersonID: integer (nullable = true)
#  |-- Freight: decimal(18,2) (nullable = true)
#  |-- loaded_at: timestamp (nullable = true)

# %%
display(df_sales_order_header, 10)
# Out:
# 26/03/05 22:13:31 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#    SalesOrderID  OrderDate    ShipDate  OnlineOrderFlag   AccountNumber  \
# 0         43828 2021-06-01  2021-07-05             True  10-4030-027605
# 1         43829 2021-06-01  2021-07-05             True  10-4030-027611
# 2         43830 2021-06-01  2021-07-05             True  10-4030-016347
# 3         43831 2021-06-01  2021-07-05             True  10-4030-011028
# 4         43832 2021-06-01  2021-07-05             True  10-4030-013584
# 5         43659 2021-05-31  2021-06-07            False  10-4020-000676
# 6         43660 2021-05-31  2021-06-07            False  10-4020-000117
# 7         43661 2021-05-31  2021-06-07            False  10-4020-000442
# 8         43662 2021-05-31  2021-06-07            False  10-4020-000227
# 9         43663 2021-05-31  2021-06-07            False  10-4020-000510
#
#    CustomerID  SalesPersonID Freight                  loaded_at
# 0       27605            NaN   89.46 2026-03-05 22:00:15.371623
# 1       27611            NaN   89.46 2026-03-05 22:00:15.371623
# 2       16347            NaN   89.46 2026-03-05 22:00:15.371623
# 3       11028            NaN   84.37 2026-03-05 22:00:15.371623
# 4       13584            NaN   89.46 2026-03-05 22:00:15.371623
# 5       29825          279.0  616.10 2026-03-05 22:00:15.371623
# 6       29672          279.0   38.83 2026-03-05 22:00:15.371623
# 7       29734          282.0  985.55 2026-03-05 22:00:15.371623
# 8       29994          282.0  867.24 2026-03-05 22:00:15.371623
# 9       29565          276.0   12.58 2026-03-05 22:00:15.371623

# %%
spark.sql(
    '''
        SELECT *
        FROM store.store_sales_order_header
        LIMIT 10;
    '''
).show(truncate=False, vertical=True)
# Out:
# -RECORD 0-------------------------------------
#  SalesOrderID    | 43828
#  OrderDate       | 2021-06-01 00:00:00
#  ShipDate        | 2021-07-05
#  OnlineOrderFlag | true
#  AccountNumber   | 10-4030-027605
#  CustomerID      | 27605
#  SalesPersonID   | NULL
#  Freight         | 89.46
#  loaded_at       | 2026-03-05 22:00:15.371623
# -RECORD 1-------------------------------------
#  SalesOrderID    | 43829
#  OrderDate       | 2021-06-01 00:00:00
#  ShipDate        | 2021-07-05
#  OnlineOrderFlag | true
#  AccountNumber   | 10-4030-027611
#  CustomerID      | 27611
#  SalesPersonID   | NULL
#  Freight         | 89.46
#  loaded_at       | 2026-03-05 22:00:15.371623
# -RECORD 2-------------------------------------
#  SalesOrderID    | 43830
#  OrderDate       | 2021-06-01 00:00:00
#  ShipDate        | 2021-07-05
#  OnlineOrderFlag | true
#  AccountNumber   | 10-4030-016347
#  CustomerID      | 16347
#  SalesPersonID   | NULL
#  Freight         | 89.46
#  loaded_at       | 2026-03-05 22:00:15.371623
# -RECORD 3-------------------------------------
#  SalesOrderID    | 43831
#  OrderDate       | 2021-06-01 00:00:00
#  ShipDate        | 2021-07-05
#  OnlineOrderFlag | true
#  AccountNumber   | 10-4030-011028
#  CustomerID      | 11028
#  SalesPersonID   | NULL
#  Freight         | 84.37
#  loaded_at       | 2026-03-05 22:00:15.371623
# -RECORD 4-------------------------------------
#  SalesOrderID    | 43832
#  OrderDate       | 2021-06-01 00:00:00
#  ShipDate        | 2021-07-05
#  OnlineOrderFlag | true
#  AccountNumber   | 10-4030-013584
#  CustomerID      | 13584
#  SalesPersonID   | NULL
#  Freight         | 89.46
#  loaded_at       | 2026-03-05 22:00:15.371623
# -RECORD 5-------------------------------------
#  SalesOrderID    | 43659
#  OrderDate       | 2021-05-31 00:00:00
#  ShipDate        | 2021-06-07
#  OnlineOrderFlag | false
#  AccountNumber   | 10-4020-000676
#  CustomerID      | 29825
#  SalesPersonID   | 279
#  Freight         | 616.10
#  loaded_at       | 2026-03-05 22:00:15.371623
# -RECORD 6-------------------------------------
#  SalesOrderID    | 43660
#  OrderDate       | 2021-05-31 00:00:00
#  ShipDate        | 2021-06-07
#  OnlineOrderFlag | false
#  AccountNumber   | 10-4020-000117
#  CustomerID      | 29672
#  SalesPersonID   | 279
#  Freight         | 38.83
#  loaded_at       | 2026-03-05 22:00:15.371623
# -RECORD 7-------------------------------------
#  SalesOrderID    | 43661
#  OrderDate       | 2021-05-31 00:00:00
#  ShipDate        | 2021-06-07
#  OnlineOrderFlag | false
#  AccountNumber   | 10-4020-000442
#  CustomerID      | 29734
#  SalesPersonID   | 282
#  Freight         | 985.55
#  loaded_at       | 2026-03-05 22:00:15.371623
# -RECORD 8-------------------------------------
#  SalesOrderID    | 43662
#  OrderDate       | 2021-05-31 00:00:00
#  ShipDate        | 2021-06-07
#  OnlineOrderFlag | false
#  AccountNumber   | 10-4020-000227
#  CustomerID      | 29994
#  SalesPersonID   | 282
#  Freight         | 867.24
#  loaded_at       | 2026-03-05 22:00:15.371623
# -RECORD 9-------------------------------------
#  SalesOrderID    | 43663
#  OrderDate       | 2021-05-31 00:00:00
#  ShipDate        | 2021-06-07
#  OnlineOrderFlag | false
#  AccountNumber   | 10-4020-000510
#  CustomerID      | 29565
#  SalesPersonID   | 276
#  Freight         | 12.58
#  loaded_at       | 2026-03-05 22:00:15.371623
