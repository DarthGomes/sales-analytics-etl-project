# %%
import pyspark.sql.functions as F

from src.spark_session import get_spark
from src.utils.display_mimic import display

spark = get_spark()
# Out:
# ...
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-fd6995a0-7ba4-4752-b939-713bed0a7cb4;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.0.0 in central
# 	found io.delta#delta-storage;3.0.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# downloading https://repo1.maven.org/maven2/io/delta/delta-spark_2.12/3.0.0/delta-spark_2.12-3.0.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-spark_2.12;3.0.0!delta-spark_2.12.jar (659ms)
# downloading https://repo1.maven.org/maven2/io/delta/delta-storage/3.0.0/delta-storage-3.0.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-storage;3.0.0!delta-storage.jar (86ms)
# ...

# %%
df_publish_products = spark.table('publish.publish_products')
# Out:
# 26/03/05 23:23:32 WARN HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 26/03/05 23:23:32 WARN HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# 26/03/05 23:23:38 WARN ObjectStore: Version information not found in metastore. hive.metastore.schema.verification is not enabled so recording the schema version 2.3.0
# 26/03/05 23:23:38 WARN ObjectStore: setMetaStoreSchemaVersion called but recording version is disabled: version = 2.3.0, comment = Set by MetaStore UNKNOWN@172.18.0.2
# 26/03/05 23:23:39 WARN ObjectStore: Failed to get database global_temp, returning NoSuchObjectException

# %%
display(df_publish_products.filter(F.col('Color').isNull()))
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductDesc, ProductNumber, MakeFlag, Color, SafetyStockLevel, ReorderPoint, Size, SizeUnitMeasureCode, WeightUnitMeasureCode, StandardCost, ListPrice, Weight, ProductCategoryName, ProductSubCategoryName, loaded_at]
# Index: []

# %%
display(df_publish_products.filter(F.col('Color') == 'N/A'), 10)
# Out:
#    ProductID             ProductDesc ProductNumber  MakeFlag Color  \
# 0        802                 LL Fork       FK-1639      True   N/A
# 1        803                 ML Fork       FK-5136      True   N/A
# 2        804                 HL Fork       FK-9939      True   N/A
# 3        805              LL Headset       HS-0296      True   N/A
# 4        806              ML Headset       HS-2451      True   N/A
# 5        807              HL Headset       HS-3479      True   N/A
# 6        808  LL Mountain Handlebars       HB-M243      True   N/A
# 7        809  ML Mountain Handlebars       HB-M763      True   N/A
# 8        810  HL Mountain Handlebars       HB-M918      True   N/A
# 9        811      LL Road Handlebars       HB-R504      True   N/A
#
#    SafetyStockLevel  ReorderPoint  Size SizeUnitMeasureCode  \
# 0               500           375  None                None
# 1               500           375  None                None
# ...

# %%
(
    display(
    df_publish_products
    .filter(F.col("ProductCategoryName").isNull() &
           (F.col("ProductSubCategoryName")
            .isin(
                "Gloves", 
                "Shorts", 
                "Socks", 
                "Tights", 
                "Vests",
                "Locks", 
                "Lights", 
                "Headsets", 
                "Helmets", 
                "Pedals", 
                "Pumps",
                "Wheels", 
                "Saddles")))
            )
)
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductDesc, ProductNumber, MakeFlag, Color, SafetyStockLevel, ReorderPoint, Size, SizeUnitMeasureCode, WeightUnitMeasureCode, StandardCost, ListPrice, Weight, ProductCategoryName, ProductSubCategoryName, loaded_at]
# Index: []
