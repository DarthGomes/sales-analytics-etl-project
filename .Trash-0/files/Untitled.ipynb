# %%
from src.spark_session import get_spark
from src.utils.display_mimic import display

spark = get_spark()
# Out:
# ...
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-2a1b6884-a8f3-44d3-a3c6-d47d4a0b5b7d;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.0.0 in central
# 	found io.delta#delta-storage;3.0.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# downloading https://repo1.maven.org/maven2/io/delta/delta-spark_2.12/3.0.0/delta-spark_2.12-3.0.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-spark_2.12;3.0.0!delta-spark_2.12.jar (566ms)
# downloading https://repo1.maven.org/maven2/io/delta/delta-storage/3.0.0/delta-storage-3.0.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-storage;3.0.0!delta-storage.jar (43ms)
# ...

# %%
df_products = spark.table('store.store_products')
df_sales_order_detail = spark.table('store.store_sales_order_detail')
df_sales_order_header = spark.table('store.store_sales_order_header')
# Out:
# 26/03/05 23:00:07 WARN HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 26/03/05 23:00:07 WARN HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# 26/03/05 23:00:13 WARN ObjectStore: Version information not found in metastore. hive.metastore.schema.verification is not enabled so recording the schema version 2.3.0
# 26/03/05 23:00:13 WARN ObjectStore: setMetaStoreSchemaVersion called but recording version is disabled: version = 2.3.0, comment = Set by MetaStore UNKNOWN@172.18.0.2
# 26/03/05 23:00:13 WARN ObjectStore: Failed to get database global_temp, returning NoSuchObjectException

# %%
df_list = [df_products, df_sales_order_detail, df_sales_order_header]

for df in df_list:
    df.printSchema()
    print('*' *10)
# Out:
# root
#  |-- ProductID: integer (nullable = true)
#  |-- ProductDesc: string (nullable = true)
#  |-- ProductNumber: string (nullable = true)
#  |-- MakeFlag: boolean (nullable = true)
#  |-- Color: string (nullable = true)
#  |-- SafetyStockLevel: integer (nullable = true)
#  |-- ReorderPoint: integer (nullable = true)
#  |-- Size: string (nullable = true)
#  |-- SizeUnitMeasureCode: string (nullable = true)
#  |-- WeightUnitMeasureCode: string (nullable = true)
#  |-- StandardCost: decimal(18,2) (nullable = true)
#  |-- ListPrice: decimal(18,2) (nullable = true)
#  |-- Weight: decimal(18,2) (nullable = true)
#  |-- ProductCategoryName: string (nullable = true)
#  |-- ProductSubCategoryName: string (nullable = true)
#  |-- loaded_at: timestamp (nullable = true)
#
# **********
# root
#  |-- SalesOrderID: integer (nullable = true)
#  |-- SalesOrderDetailID: integer (nullable = true)
#  |-- OrderQty: integer (nullable = true)
#  |-- ProductID: integer (nullable = true)
# ...
